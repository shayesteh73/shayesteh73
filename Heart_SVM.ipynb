# %%
# Import Libararies

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score
from sklearn import metrics
from sklearn.model_selection import GridSearchCV

# %%
# Import Dataset

data=pd.read_csv("/content/drive/MyDrive/heart-1.csv")

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
# Dataset Overview

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df=data.rename(columns={'cp' : 'chest_pain_type', 'trestbps' : 'resting_blood_pressure', 'chol' : 'cholesterol',
                        'fbs' : 'fasting_blood_sugar','restecg' : 'resting_electrocardiogram','thalach' : 'max_heart_rate_achieved',
                        'exang' : 'exercise_ininduced_angina','oldpeak' : 'st_depression','slope' : 'st_slope','ca' : 'num_major_vessels','thal' : 'thalassemia'},errors="raise")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   age                        1025 non-null   int64
#  1   sex                        1025 non-null   int64
#  2   chest_pain_type            1025 non-null   int64
#  3   resting_blood_pressure     1025 non-null   int64
#  4   cholesterol                1025 non-null   int64
#  5   fasting_blood_sugar        1025 non-null   int64
#  6   resting_electrocardiogram  1025 non-null   int64
#  7   max_heart_rate_achieved    1025 non-null   int64
#  8   exercise_ininduced_angina  1025 non-null   int64
#  9   st_depression              1025 non-null   float64
#  10  st_slope                   1025 non-null   int64
#  11  num_major_vessels          1025 non-null   int64
#  12  thalassemia                1025 non-null   int64
#  13  target                     1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.head()
# Out:
#    age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 0   52    1                0                     125          212
# 1   53    1                0                     140          203
# 2   70    1                0                     145          174
# 3   61    1                0                     148          203
# 4   62    0                0                     138          294
#
#    fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 0                    0                          1                      168
# 1                    1                          0                      155
# 2                    0                          1                      125
# 3                    0                          1                      161
# 4                    1                          1                      106
#
#    exercise_ininduced_angina  st_depression  st_slope  num_major_vessels  \
# 0                          0            1.0         2                  2
# 1                          1            3.1         0                  0
# 2                          1            2.6         0                  0
# 3                          0            0.0         2                  1
# 4                          0            1.9         1                  3
#
#    thalassemia  target
# 0            3       0
# 1            3       0
# 2            3       0
# 3            3       0
# 4            2       0

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.isnull().sum()
# Out:
# age                          0
# sex                          0
# chest_pain_type              0
# resting_blood_pressure       0
# cholesterol                  0
# fasting_blood_sugar          0
# resting_electrocardiogram    0
# max_heart_rate_achieved      0
# exercise_ininduced_angina    0
# st_depression                0
# st_slope                     0
# num_major_vessels            0
# thalassemia                  0
# target                       0
# dtype: int64

# %%
df['target'].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
df['target'].value_counts()/df.shape[0]*100
# Out:
# 1    51.317073
# 0    48.682927
# Name: target, dtype: float64

# %%
df.corr()['target'].sort_values(ascending=False)
# Out:
# target                       1.000000
# chest_pain_type              0.434854
# max_heart_rate_achieved      0.422895
# st_slope                     0.345512
# resting_electrocardiogram    0.134468
# fasting_blood_sugar         -0.041164
# cholesterol                 -0.099966
# resting_blood_pressure      -0.138772
# age                         -0.229324
# sex                         -0.279501
# thalassemia                 -0.337838
# num_major_vessels           -0.382085
# exercise_ininduced_angina   -0.438029
# st_depression               -0.438441
# Name: target, dtype: float64

# %%
mypal=['#FC05FB', '#FEAEFE', '#FCD2FC','#F3FEFA', '#B4FFE4', '#3FFEBA']
plt.figure(figsize=(7,5),facecolor='#F6F5F4')
ax=sns.countplot(x=df['target'],palette=mypal[1:4])

ax.set_title("Target variable distribution", fontsize=20, y=1.05)
# Out:
# <ipython-input-162-82b37e07eec9>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df['target'],palette=mypal[1:4])
# <ipython-input-162-82b37e07eec9>:3: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   ax=sns.countplot(x=df['target'],palette=mypal[1:4])
# Text(0.5, 1.05, 'Target variable distribution')

# %%
corr_df=df[['chest_pain_type','max_heart_rate_achieved','st_slope','resting_electrocardiogram']]

# %%
plt.figure(figsize=(20,10))
sns.heatmap(corr_df.corr(),annot=True,linewidth=2)
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df, x='max_heart_rate_achieved', y='resting_blood_pressure', hue='target')
# Out:
# <Axes: xlabel='max_heart_rate_achieved', ylabel='resting_blood_pressure'>

# %%
plt.figure(figsize =(10,5))
sns.scatterplot(data=df)
# Out:
# <Axes: >

# %%
categorical_features = ['sex', 'chest_pain_type', 'fasting_blood_sugar', 'resting_electrocardiogram', 'exercise_induced_angina','st_slope','thalassemia']
numerical_features = ['age', 'resting_blood_pressure', 'cholesterol', 'max_heart_rate_achieved','st_depression', 'num_major_vessels']

print('Categorical Features are :', categorical_features)

print('Continuous Features are : ', numerical_features)
# Out:
# Categorical Features are : ['sex', 'chest_pain_type', 'fasting_blood_sugar', 'resting_electrocardiogram', 'exercise_induced_angina', 'st_slope', 'thalassemia']
# Continuous Features are :  ['age', 'resting_blood_pressure', 'cholesterol', 'max_heart_rate_achieved', 'st_depression', 'num_major_vessels']

# %%
# Visulazing Numerical Features

sns.pairplot(df[['age', 'resting_blood_pressure', 'cholesterol', 'max_heart_rate_achieved','st_depression', 'num_major_vessels']])

# %%
plt.figure(figsize = (10,5))

sns.boxplot(df[['age', 'resting_blood_pressure', 'cholesterol', 'max_heart_rate_achieved','st_depression', 'num_major_vessels']])
# Out:
# <Axes: >

# %%
# Data prepration (pre_processing)

# removing outlier data for age

sns.boxplot(df, x='target' , y='age')
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
df[(df['age'] == 35) & (df['target'] == 0)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 254   35    1                0                     120          198
# 384   35    1                0                     126          282
# 695   35    1                0                     126          282
# 699   35    1                0                     126          282
# 701   35    1                0                     120          198
# 711   35    1                0                     120          198
# 912   35    1                0                     120          198
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 254                    0                          1                      130
# 384                    0                          0                      156
# 695                    0                          0                      156
# 699                    0                          0                      156
# 701                    0                          1                      130
# 711                    0                          1                      130
# 912                    0                          1                      130
#
#      exercise_ininduced_angina  st_depression  st_slope  num_major_vessels  \
# 254                          1            1.6         1                  0
# 384                          1            0.0         2                  0
# 695                          1            0.0         2                  0
# 699                          1            0.0         2                  0
# 701                          1            1.6         1                  0
# 711                          1            1.6         1                  0
# 912                          1            1.6         1                  0
#
#      thalassemia  target
# 254            3       0
# 384            3       0
# 695            3       0
# 699            3       0
# 701            3       0
# 711            3       0
# 912            3       0

# %%
index_drop_age_0 = df[(df['age'] == 35) & (df['target'] == 0)].index
df = df.drop(index_drop_age_0, axis=0)

# %%
# Removing outlier data for resting_blood_pressure

sns.boxplot(df, x='target', y='resting_blood_pressure')
# Out:
# <Axes: xlabel='target', ylabel='resting_blood_pressure'>

# %%
df[(df['resting_blood_pressure'] >= 190) & (df['resting_blood_pressure'] <=200) & (df['target'] == 0 )].index
# Out:
# Int64Index([151, 175, 246, 294, 326, 508, 688], dtype='int64')

# %%
index_drop_resting_blood_pressure_0 = df[(df['resting_blood_pressure'] >=190) & (df['resting_blood_pressure'] <= 200) & (df['target'] == 0)].index
df = df.drop(index_drop_resting_blood_pressure_0, axis = 0)

# %%
df[(df['resting_blood_pressure'] >= 170) & (df['resting_blood_pressure'] <=185) & (df['target'] == 1)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 137   64    0                0                     180          325
# 203   64    1                3                     170          227
# 235   64    1                3                     170          227
# 257   64    0                0                     180          325
# 343   52    1                2                     172          199
# 528   59    1                3                     178          270
# 539   64    1                3                     170          227
# 624   59    1                3                     178          270
# 837   52    1                2                     172          199
# 872   64    1                3                     170          227
# 891   64    0                0                     180          325
# 896   59    1                3                     178          270
# 971   52    1                2                     172          199
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 137                    0                          1                      154
# 203                    0                          0                      155
# 235                    0                          0                      155
# 257                    0                          1                      154
# 343                    1                          1                      162
# 528                    0                          0                      145
# 539                    0                          0                      155
# 624                    0                          0                      145
# 837                    1                          1                      162
# 872                    0                          0                      155
# 891                    0                          1                      154
# 896                    0                          0                      145
# 971                    1                          1                      162
#
#      exercise_ininduced_angina  st_depression  st_slope  num_major_vessels  \
# 137                          1            0.0         2                  0
# 203                          0            0.6         1                  0
# 235                          0            0.6         1                  0
# 257                          1            0.0         2                  0
# 343                          0            0.5         2                  0
# 528                          0            4.2         0                  0
# 539                          0            0.6         1                  0
# 624                          0            4.2         0                  0
# 837                          0            0.5         2                  0
# 872                          0            0.6         1                  0
# 891                          1            0.0         2                  0
# 896                          0            4.2         0                  0
# 971                          0            0.5         2                  0
#
#      thalassemia  target
# 137            2       1
# 203            3       1
# 235            3       1
# 257            2       1
# 343            3       1
# 528            3       1
# 539            3       1
# 624            3       1
# 837            3       1
# 872            3       1
# 891            2       1
# 896            3       1
# 971            3       1

# %%
index_drop_resting_blood_pressure_1 = df[(df['resting_blood_pressure'] >= 170) & (df['resting_blood_pressure'] <= 185) & (df['target'] == 1)].index
df = df.drop(index_drop_resting_blood_pressure_1, axis = 0)

# %%
sns.boxplot(df, x='target' , y='cholesterol')
# Out:
# <Axes: xlabel='target', ylabel='cholesterol'>

# %%
df[(df['cholesterol'] >=400) & (df['cholesterol'] <= 410) & (df['target'] == 0)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 179   56    0                0                     134          409
# 450   63    0                0                     150          407
# 481   63    0                0                     150          407
# 641   56    0                0                     134          409
# 685   63    0                0                     150          407
# 889   63    0                0                     150          407
# 996   56    0                0                     134          409
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 179                    0                          0                      150
# 450                    0                          0                      154
# 481                    0                          0                      154
# 641                    0                          0                      150
# 685                    0                          0                      154
# 889                    0                          0                      154
# 996                    0                          0                      150
#
#      exercise_ininduced_angina  st_depression  st_slope  num_major_vessels  \
# 179                          1            1.9         1                  2
# 450                          0            4.0         1                  3
# 481                          0            4.0         1                  3
# 641                          1            1.9         1                  2
# 685                          0            4.0         1                  3
# 889                          0            4.0         1                  3
# 996                          1            1.9         1                  2
#
#      thalassemia  target
# 179            3       0
# 450            3       0
# 481            3       0
# 641            3       0
# 685            3       0
# 889            3       0
# 996            3       0

# %%
index_drop_cholesterol_0 = df[(df['cholesterol'] >= 400) & (df['target'] == 0)].index
df = df.drop(index_drop_cholesterol_0, axis=0)

# %%
df[(df['cholesterol'] >= 350) & (df['cholesterol'] <= 450) & (df['target'] == 1)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 40    65    0                2                     160          360
# 123   65    0                2                     140          417
# 167   57    0                0                     120          354
# 255   62    0                0                     140          394
# 419   65    0                2                     160          360
# 422   57    0                0                     120          354
# 435   57    0                0                     120          354
# 542   62    0                0                     140          394
# 578   62    0                0                     140          394
# 665   65    0                2                     140          417
# 751   65    0                2                     160          360
# 958   65    0                2                     140          417
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 40                     0                          0                      151
# 123                    1                          0                      157
# 167                    0                          1                      163
# 255                    0                          0                      157
# 419                    0                          0                      151
# 422                    0                          1                      163
# 435                    0                          1                      163
# 542                    0                          0                      157
# 578                    0                          0                      157
# 665                    1                          0                      157
# 751                    0                          0                      151
# 958                    1                          0                      157
#
#      exercise_ininduced_angina  st_depression  st_slope  num_major_vessels  \
# 40                           0            0.8         2                  0
# 123                          0            0.8         2                  1
# 167                          1            0.6         2                  0
# 255                          0            1.2         1                  0
# 419                          0            0.8         2                  0
# 422                          1            0.6         2                  0
# 435                          1            0.6         2                  0
# 542                          0            1.2         1                  0
# 578                          0            1.2         1                  0
# 665                          0            0.8         2                  1
# 751                          0            0.8         2                  0
# 958                          0            0.8         2                  1
#
#      thalassemia  target
# 40             2       1
# 123            2       1
# 167            2       1
# 255            2       1
# 419            2       1
# 422            2       1
# 435            2       1
# 542            2       1
# 578            2       1
# 665            2       1
# 751            2       1
# 958            2       1

# %%
index_drop_cholesterol_1 = df[(df['cholesterol'] >= 350) & (df['cholesterol'] <= 450 ) & (df['target'] == 1)].index
df =  df.drop(index_drop_cholesterol_1, axis = 0)

# %%
df[(df['cholesterol'] < 600) & (df['target'] == 1)].tail(10)
# Out:
#       age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 1003   52    1                0                     108          233
# 1004   51    0                2                     140          308
# 1006   58    1                2                     140          211
# 1007   56    1                3                     120          193
# 1008   42    1                1                     120          295
# 1011   45    1                1                     128          308
# 1014   44    0                2                     108          141
# 1019   47    1                0                     112          204
# 1020   59    1                1                     140          221
# 1023   50    0                0                     110          254
#
#       fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 1003                    1                          1                      147
# 1004                    0                          0                      142
# 1006                    1                          0                      165
# 1007                    0                          0                      162
# 1008                    0                          1                      162
# 1011                    0                          0                      170
# 1014                    0                          1                      175
# 1019                    0                          1                      143
# 1020                    0                          1                      164
# 1023                    0                          0                      159
#
#       exercise_ininduced_angina  st_depression  st_slope  num_major_vessels  \
# 1003                          0            0.1         2                  3
# 1004                          0            1.5         2                  1
# 1006                          0            0.0         2                  0
# 1007                          0            1.9         1                  0
# 1008                          0            0.0         2                  0
# 1011                          0            0.0         2                  0
# 1014                          0            0.6         1                  0
# 1019                          0            0.1         2                  0
# 1020                          1            0.0         2                  0
# 1023                          0            0.0         2                  0
#
#       thalassemia  target
# 1003            3       1
# 1004            2       1
# 1006            2       1
# 1007            3       1
# 1008            2       1
# 1011            2       1
# 1014            2       1
# 1019            2       1
# 1020            2       1
# 1023            2       1

# %%
index_drop_cholesterol_1 = df[(df['cholesterol'] < 600) & (df['target'] == 1)].tail(10).index
df = df.drop(index_drop_cholesterol_1, axis = 0)

# %%
# Removing outlier data for resting_blood_pressure

sns.boxplot(df, x='target' , y='max_heart_rate_achieved')
# Out:
# <Axes: xlabel='target', ylabel='max_heart_rate_achieved'>

# %%
df[(df['max_heart_rate_achieved'] < 80) & (df['target'] == 0)].head()
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 267   67    1                0                     120          237
# 296   67    1                0                     120          237
# 378   67    1                0                     120          237
# 559   67    1                0                     120          237
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 267                    0                          1                       71
# 296                    0                          1                       71
# 378                    0                          1                       71
# 559                    0                          1                       71
#
#      exercise_ininduced_angina  st_depression  st_slope  num_major_vessels  \
# 267                          0            1.0         1                  0
# 296                          0            1.0         1                  0
# 378                          0            1.0         1                  0
# 559                          0            1.0         1                  0
#
#      thalassemia  target
# 267            2       0
# 296            2       0
# 378            2       0
# 559            2       0

# %%
index_drop_max_heart_rate_achieved_0 = df[(df['max_heart_rate_achieved'] < 80) & (df['target'] == 0)].head(40).index
df = df.drop(index_drop_max_heart_rate_achieved_0, axis = 0)

# %%
df[(df['max_heart_rate_achieved'] >= 90) & (df['max_heart_rate_achieved'] <= 100) & (df['target'] == 1)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 708   60    0                2                     120          178
# 793   60    0                2                     120          178
# 967   60    0                2                     120          178
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 708                    1                          1                       96
# 793                    1                          1                       96
# 967                    1                          1                       96
#
#      exercise_ininduced_angina  st_depression  st_slope  num_major_vessels  \
# 708                          0            0.0         2                  0
# 793                          0            0.0         2                  0
# 967                          0            0.0         2                  0
#
#      thalassemia  target
# 708            2       1
# 793            2       1
# 967            2       1

# %%
index_drop_max_heart_rate_achieved_1 = df[(df['max_heart_rate_achieved'] >= 90) & (df['max_heart_rate_achieved'] <= 100) & (df['target'] == 1)].index
df = df.drop(index_drop_max_heart_rate_achieved_1, axis=0)

# %%
df[(df['max_heart_rate_achieved'] >= 100) & (df['max_heart_rate_achieved'] <= 110) & (df['target'] == 1)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 38    64    1                0                     128          263
# 642   64    1                0                     128          263
# 983   64    1                0                     128          263
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 38                     0                          1                      105
# 642                    0                          1                      105
# 983                    0                          1                      105
#
#      exercise_ininduced_angina  st_depression  st_slope  num_major_vessels  \
# 38                           1            0.2         1                  1
# 642                          1            0.2         1                  1
# 983                          1            0.2         1                  1
#
#      thalassemia  target
# 38             3       1
# 642            3       1
# 983            3       1

# %%
index_drop_max_heart_rate_achieved_1 = df[(df['max_heart_rate_achieved'] >= 100) & (df['max_heart_rate_achieved'] <= 110) & (df['target'] == 1)].index
df = df.drop(index_drop_max_heart_rate_achieved_1, axis = 0)

# %%
sns.boxplot(df , x='target' , y='st_depression')
# Out:
# <Axes: xlabel='target', ylabel='st_depression'>

# %%
df[(df['st_depression'] >= 5.5) & (df['st_depression'] <= 6.5) & (df['target'] == 0)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 54    55    1                0                     140          217
# 55    55    1                0                     140          217
# 69    62    0                0                     160          164
# 393   62    0                0                     160          164
# 526   62    0                0                     160          164
# 613   55    1                0                     140          217
# 833   55    1                0                     140          217
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 54                     0                          1                      111
# 55                     0                          1                      111
# 69                     0                          0                      145
# 393                    0                          0                      145
# 526                    0                          0                      145
# 613                    0                          1                      111
# 833                    0                          1                      111
#
#      exercise_ininduced_angina  st_depression  st_slope  num_major_vessels  \
# 54                           1            5.6         0                  0
# 55                           1            5.6         0                  0
# 69                           0            6.2         0                  3
# 393                          0            6.2         0                  3
# 526                          0            6.2         0                  3
# 613                          1            5.6         0                  0
# 833                          1            5.6         0                  0
#
#      thalassemia  target
# 54             3       0
# 55             3       0
# 69             3       0
# 393            3       0
# 526            3       0
# 613            3       0
# 833            3       0

# %%
index_drop_st_depression_0 = df[(df['st_depression'] >= 5.5) & (df['st_depression'] <= 6.5) & (df['target'] == 0)].index
df = df.drop(index_drop_st_depression_0, axis = 0)

# %%
df[(df['st_depression'] >= 2.5) & (df['st_depression'] < 4) & (df['target'] == 1)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 22    45    1                0                     104          208
# 265   45    1                0                     104          208
# 332   37    1                2                     130          250
# 433   37    1                2                     130          250
# 652   66    0                3                     150          226
# 664   66    0                3                     150          226
# 713   66    0                3                     150          226
# 851   37    1                2                     130          250
# 913   45    1                0                     104          208
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 22                     0                          0                      148
# 265                    0                          0                      148
# 332                    0                          1                      187
# 433                    0                          1                      187
# 652                    0                          1                      114
# 664                    0                          1                      114
# 713                    0                          1                      114
# 851                    0                          1                      187
# 913                    0                          0                      148
#
#      exercise_ininduced_angina  st_depression  st_slope  num_major_vessels  \
# 22                           1            3.0         1                  0
# 265                          1            3.0         1                  0
# 332                          0            3.5         0                  0
# 433                          0            3.5         0                  0
# 652                          0            2.6         0                  0
# 664                          0            2.6         0                  0
# 713                          0            2.6         0                  0
# 851                          0            3.5         0                  0
# 913                          1            3.0         1                  0
#
#      thalassemia  target
# 22             2       1
# 265            2       1
# 332            2       1
# 433            2       1
# 652            2       1
# 664            2       1
# 713            2       1
# 851            2       1
# 913            2       1

# %%
index_drop_st_depression_1 = df[(df['st_depression'] >= 2.5) & (df['st_depression'] < 4) & (df['target'] == 1)].index
df = df.drop(index_drop_st_depression_1, axis = 0)

# %%
# removing outlier data for num_major_vessels
sns.boxplot(df, x='target' , y='num_major_vessels')
# Out:
# <Axes: xlabel='target', ylabel='num_major_vessels'>

# %%
num_vessels_list=[1,2,3,4,5]
df[(df['target'] == 1) & df['num_major_vessels'].isin(num_vessels_list)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 16    51    0                2                     140          308
# 21    67    0                0                     106          223
# 36    51    1                3                     125          213
# 48    66    0                2                     146          278
# 52    38    1                2                     138          175
# ..   ...  ...              ...                     ...          ...
# 962   52    1                0                     108          233
# 970   38    1                2                     138          175
# 982   67    0                0                     106          223
# 985   62    1                2                     130          231
# 989   71    0                1                     160          302
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 16                     0                          0                      142
# 21                     0                          1                      142
# 36                     0                          0                      125
# 48                     0                          0                      152
# 52                     0                          1                      173
# ..                   ...                        ...                      ...
# 962                    1                          1                      147
# 970                    0                          1                      173
# 982                    0                          1                      142
# 985                    0                          1                      146
# 989                    0                          1                      162
#
#      exercise_ininduced_angina  st_depression  st_slope  num_major_vessels  \
# 16                           0            1.5         2                  1
# 21                           0            0.3         2                  2
# 36                           1            1.4         2                  1
# 48                           0            0.0         1                  1
# 52                           0            0.0         2                  4
# ..                         ...            ...       ...                ...
# 962                          0            0.1         2                  3
# 970                          0            0.0         2                  4
# 982                          0            0.3         2                  2
# 985                          0            1.8         1                  3
# 989                          0            0.4         2                  2
#
#      thalassemia  target
# 16             2       1
# 21             2       1
# 36             2       1
# 48             2       1
# 52             2       1
# ..           ...     ...
# 962            3       1
# 970            2       1
# 982            2       1
# 985            3       1
# 989            2       1
#
# [103 rows x 14 columns]

# %%
index_drop_num_major_vessels_1 = df[(df['target'] == 1) & df['num_major_vessels'].isin(num_vessels_list)].index
df = df.drop(index_drop_num_major_vessels_1, axis = 0)

# %%
# Scaling the Features

scaler = StandardScaler()

# %%
# scale selected data

df[numerical_features] = scaler.fit_transform(df[numerical_features])

# %%
df.head()
# Out:
#         age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 0 -0.235473    1                0               -0.346773    -0.653636
# 1 -0.121796    1                0                0.591054    -0.839197
# 2  1.810704    1                0                0.903663    -1.437116
# 3  0.787616    1                0                1.091228    -0.839197
# 4  0.901292    0                0                0.466011     1.037031
#
#    fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 0                    0                          1                 0.828245
# 1                    1                          0                 0.263673
# 2                    0                          1                -1.039183
# 3                    0                          1                 0.524245
# 4                    1                          1                -1.864326
#
#    exercise_ininduced_angina  st_depression  st_slope  num_major_vessels  \
# 0                          0      -0.070863         2           1.427859
# 1                          1       1.849288         0          -0.676354
# 2                          1       1.392109         0          -0.676354
# 3                          0      -0.985220         2           0.375752
# 4                          0       0.752059         1           2.479965
#
#    thalassemia  target
# 0            3       0
# 1            3       0
# 2            3       0
# 3            3       0
# 4            2       0

# %%
# Determine the features & target label
X = df.drop('target' ,axis=1)
y=df['target']

# %%
# Split the dataset to train & test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
# Train the model using the x_train & y_train

svm_model = SVC()

# %%
svm_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
# Predicting test data

y_pred = svm_model.predict(X_test)

# %%
# The prediction value vs actual value of test data

pd.DataFrame({'Y_Test' : y_test, 'Y_pred' : y_pred}).head(10)
# Out:
#      Y_Test  Y_pred
# 940       0       0
# 740       1       1
# 355       1       1
# 443       1       1
# 66        1       1
# 525       1       1
# 530       0       0
# 875       0       0
# 727       1       1
# 503       1       1

# %%
# Evaluating the model


accuracy_score(y_test, y_pred)
# Out:
# 0.8809523809523809

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[114,  20],
#        [ 10, 108]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88       134
#            1       0.84      0.92      0.88       118
#
#     accuracy                           0.88       252
#    macro avg       0.88      0.88      0.88       252
# weighted avg       0.88      0.88      0.88       252

# %%
# Hyperparameters

svm = SVC()
param_gride = {'C' : [0.01,0.1,1,10,100,1000], 'gamma' :[1,0.1,0.01,0.001,0.0001],'kernel' :['linear','rbf']}
grid = GridSearchCV(svm,param_gride, cv=5)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['linear', 'rbf']})

# %%
grid.best_estimator_
# Out:
# SVC(C=10, gamma=0.1)

# %%
grid.best_params_
# Out:
# {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
y_pred_grid = grid.predict(X_test)

# %%
accuracy_score(y_test, y_pred_grid)
# Out:
# 0.9682539682539683

# %%
print(classification_report(y_test, y_pred_grid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       134
#            1       0.97      0.96      0.97       118
#
#     accuracy                           0.97       252
#    macro avg       0.97      0.97      0.97       252
# weighted avg       0.97      0.97      0.97       252
